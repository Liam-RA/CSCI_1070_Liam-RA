# %%
import pandas as pd
import numpy as np

pd.read_csv('loans_full_schema.csv')
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...

# %% [markdown]
# Hypothesis annual income will have the most positive correlation with paid back loans

# %%
df_clothes = pd.DataFrame(data = [['green','M',10,'shirt'],
                                   ['red','M',60,'sweatshirt'],
                                   ['black','M',120,'shoes']])
df_clothes.columns('color','size','price','type')
df_clothes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 df_clothes = pd.DataFrame(data = [['green','M',10,'shirt'],
#       2                                    ['red','M',60,'sweatshirt'],
#       3                                    ['black','M',120,'shoes']])
# ----> 4 df_clothes.columns('color','size','price','type')
#       5 df_clothes
#
# TypeError: 'RangeIndex' object is not callable

# %%
size_map = {'S':1,'M':2,'L':3}
df_clothes['Size
