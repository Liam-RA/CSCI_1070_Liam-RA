# %% [markdown]
# multipe linear regression =
#
# y =m1x1 + m2x2 + m3x3....... +b
#
# Multivariate = result is a vector(multiple result values)
#
# use mean squared error and R^2 to vcalidate model performance

# %% [markdown]
# #knn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28fc43716d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28fc4371b20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28fc4371430>],
#  'medians': [<matplotlib.lines.Line2D at 0x28fc437f070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28fc437f310>],
#  'means': []}

# %%
x = df.drop('Outcome',axis=1)
y = df['Outcome']

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size =0.3, random_state=32)

#standardizing
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

knn = KNeighborsClassifier(n_neighbors=32)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=32)

# %%
predict_df = pd.DataFrame(x_test,columns = df.columns[0:8])
predict_df['Actual Outcome'] = y_test.tolist()
predict_df['Predicted_Outcome'] = y_predict.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 predict_df = pd.DataFrame(x_test,columns = df.columns[0:8])
#       2 predict_df['Actual Outcome'] = y_test.tolist()
# ----> 3 predict_df['Predicted_Outcome'] = y_predict.tolist()
#
# NameError: name 'y_predict' is not defined

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
confusion_matrix(y_test,y_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
# ----> 2 confusion_matrix(y_test,y_predict)
#
# NameError: name 'y_predict' is not defined

# %%
ConfusionMatrixDisplay.from_estimator(knn,x_test,y_test)
