# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]

for i in months:
    
    if i == 'April':
        
        print(i + ' is my birthday')
# Out:
# April is my birthday

# %% [markdown]
# ![Screenshot 2024-01-24 204225.png](attachment:8506d9d7-c2d4-4239-8477-98c2e92e171b.png)
